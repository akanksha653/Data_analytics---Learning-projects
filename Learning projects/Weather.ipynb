# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\code.folder\New folder\DATA\sample_weather_data.csv')

# %%
data
# Out:
#            Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  \
# 0    2024-01-01             27.5          83.9               14.4
# 1    2024-01-02             24.3          77.0                5.6
# 2    2024-01-03             28.2          74.9                4.3
# 3    2024-01-04             32.6          75.1               13.0
# 4    2024-01-05             23.8          58.0                3.4
# ..          ...              ...           ...                ...
# 195  2024-07-14             26.9          45.9                8.6
# 196  2024-07-15             20.6          45.9                5.3
# 197  2024-07-16             25.8          72.5               14.8
# 198  2024-07-17             25.3          77.3                9.1
# 199  2024-07-18             19.3          69.2                3.6
#
#      Rainfall (mm) Condition  UV Index
# 0              0.2    Cloudy         2
# 1              0.3     Rainy         7
# 2              0.6    Stormy         1
# ...

# %%
data.head()
# Out:
#          Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  \
# 0  2024-01-01             27.5          83.9               14.4
# 1  2024-01-02             24.3          77.0                5.6
# 2  2024-01-03             28.2          74.9                4.3
# 3  2024-01-04             32.6          75.1               13.0
# 4  2024-01-05             23.8          58.0                3.4
#
#    Rainfall (mm) Condition  UV Index
# 0            0.2    Cloudy         2
# 1            0.3     Rainy         7
# 2            0.6    Stormy         1
# 3            0.4     Sunny        10
# 4            0.4     Foggy         6

# %%
data.shape
# Out:
# (200, 7)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
data.columns
# Out:
# Index(['Date', 'Temperature (C)', 'Humidity (%)', 'Wind Speed (km/h)',
#        'Rainfall (mm)', 'Condition', 'UV Index'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date                  object
# Temperature (C)      float64
# Humidity (%)         float64
# Wind Speed (km/h)    float64
# Rainfall (mm)        float64
# Condition             object
# UV Index               int64
# dtype: object

# %%
data['Condition'].unique()
# Out:
# array(['Cloudy', 'Rainy', 'Stormy', 'Sunny', 'Foggy'], dtype=object)

# %%
data['Condition'].nunique()
# Out:
# 5

# %%
data.nunique()
# Out:
# Date                 200
# Temperature (C)      122
# Humidity (%)         164
# Wind Speed (km/h)    116
# Rainfall (mm)         58
# Condition              5
# UV Index              11
# dtype: int64

# %%
data.count()
# Out:
# Date                 200
# Temperature (C)      200
# Humidity (%)         200
# Wind Speed (km/h)    200
# Rainfall (mm)        200
# Condition            200
# UV Index             200
# dtype: int64

# %%
data['Condition'].value_counts()
# Out:
# Condition
# Cloudy    46
# Sunny     42
# Rainy     41
# Foggy     40
# Stormy    31
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               200 non-null    object
#  1   Temperature (C)    200 non-null    float64
#  2   Humidity (%)       200 non-null    float64
#  3   Wind Speed (km/h)  200 non-null    float64
#  4   Rainfall (mm)      200 non-null    float64
#  5   Condition          200 non-null    object
#  6   UV Index           200 non-null    int64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 11.1+ KB

# %%
data[data.Condition == 'Sunny'].head(2)
# Out:
#           Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  \
# 3   2024-01-04             32.6          75.1               13.0
# 11  2024-01-12             22.7          65.1               14.9
#
#     Rainfall (mm) Condition  UV Index
# 3             0.4     Sunny        10
# 11            8.1     Sunny         9

# %%
#data.groupby('Condition').get_group('Cloudy')

# %%
data[data['Wind Speed (km/h)'] >= 14].head(2)
# Out:
#          Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  \
# 0  2024-01-01             27.5          83.9               14.4
# 5  2024-01-06             23.8          54.7               14.4
#
#    Rainfall (mm) Condition  UV Index
# 0            0.2    Cloudy         2
# 5            0.7     Rainy         1

# %%
#data.isnull()
data.isnull().sum()
# Out:
# Date                 0
# Temperature (C)      0
# Humidity (%)         0
# Wind Speed (km/h)    0
# Rainfall (mm)        0
# Condition            0
# UV Index             0
# dtype: int64

# %%
#rename column name 
#data.rename (columns = {'Rainfall (mm)': 'rainfall (barish)'},inplace=False) # when inplace is false it will not change the original data
data.rename (columns = {'rainfall (barish)': 'rainrate'},inplace=True) # when inplace is true it will change the original data

# %%
data.head()
# Out:
#          Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  rainrate  \
# 0  2024-01-01             27.5          83.9               14.4       0.2
# 1  2024-01-02             24.3          77.0                5.6       0.3
# 2  2024-01-03             28.2          74.9                4.3       0.6
# 3  2024-01-04             32.6          75.1               13.0       0.4
# 4  2024-01-05             23.8          58.0                3.4       0.4
#
#   Condition  UV Index
# 0    Cloudy         2
# 1     Rainy         7
# 2    Stormy         1
# 3     Sunny        10
# 4     Foggy         6

# %%
#mean

data.rainrate.mean()
# Out:
# np.float64(1.9494999999999998)

# %%
# standard deviation
data.rainrate.std()
# Out:
# np.float64(1.9201391673809878)

# %%
# variance
data.rainrate.var()
# Out:
# np.float64(3.6869344221105527)

# %%
data["Condition"].value_counts()
# Out:
# Condition
# Cloudy    46
# Sunny     42
# Rainy     41
# Foggy     40
# Stormy    31
# Name: count, dtype: int64

# %%
data[data["Condition"] == "Sunny"]
# Out:
#            Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  rainrate  \
# 3    2024-01-04             32.6          75.1               13.0       0.4
# 11   2024-01-12             22.7          65.1               14.9       8.1
# 15   2024-01-16             22.2          79.8                7.8       4.0
# 16   2024-01-17             19.9          84.5                9.4       3.4
# 20   2024-01-21             32.3          68.9                8.8       5.3
# 24   2024-01-25             22.3          54.3               14.3       2.9
# 35   2024-02-05             18.9          44.3               14.8       1.3
# 45   2024-02-15             21.4          53.5               10.9       2.3
# 56   2024-02-26             20.8          67.5                8.9       5.6
# 64   2024-03-05             29.1          61.0                0.8       0.5
# 67   2024-03-08             30.0          77.9               15.0       3.4
# ...

# %%
data[data["Condition"] .str.contains("Sunny")].tail(10)
# Out:
#            Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  \
# 173  2024-06-22             26.7          81.1                3.6
# 175  2024-06-24             29.1          44.1                5.7
# 177  2024-06-26             32.3          89.3                4.8
# 178  2024-06-27             23.7          58.7                3.2
# 182  2024-07-01             19.6          89.3                8.9
# 184  2024-07-03             23.9          58.8               11.8
# 186  2024-07-05             27.4          78.9                1.3
# 190  2024-07-09             22.8          45.6                6.5
# 194  2024-07-13             25.9          42.8                9.7
# 199  2024-07-18             19.3          69.2                3.6
#
#      Rainfall (mm) Condition  UV Index
# 173            0.9     Sunny        10
# 175            2.0     Sunny         8
# 177            2.2     Sunny         8
# 178            0.4     Sunny         4
# 182            0.2     Sunny         5
# ...

# %%
data[(data["Condition"]== "Sunny") | (data["Wind Speed (km/h)"] < 10)]
# Out:
#            Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  \
# 1    2024-01-02             24.3          77.0                5.6
# 2    2024-01-03             28.2          74.9                4.3
# 3    2024-01-04             32.6          75.1               13.0
# 4    2024-01-05             23.8          58.0                3.4
# 6    2024-01-07             32.9          80.5                0.2
# ..          ...              ...           ...                ...
# 194  2024-07-13             25.9          42.8                9.7
# 195  2024-07-14             26.9          45.9                8.6
# 196  2024-07-15             20.6          45.9                5.3
# 198  2024-07-17             25.3          77.3                9.1
# 199  2024-07-18             19.3          69.2                3.6
#
#      Rainfall (mm) Condition  UV Index
# 1              0.3     Rainy         7
# 2              0.6    Stormy         1
# 3              0.4     Sunny        10
# ...

# %%
data[((data["Condition"] == "Sunny") & (data["Wind Speed (km/h)"] > 10)) | (data["UV Index"] > 5)]
# Out:
#            Date  Temperature (C)  Humidity (%)  Wind Speed (km/h)  \
# 1    2024-01-02             24.3          77.0                5.6
# 3    2024-01-04             32.6          75.1               13.0
# 4    2024-01-05             23.8          58.0                3.4
# 7    2024-01-08             28.8          80.5               14.5
# 10   2024-01-11             22.7          65.6                7.9
# ..          ...              ...           ...                ...
# 190  2024-07-09             22.8          45.6                6.5
# 191  2024-07-10             29.3          64.6                1.9
# 192  2024-07-11             26.1          40.6                4.3
# 194  2024-07-13             25.9          42.8                9.7
# 198  2024-07-17             25.3          77.3                9.1
#
#      Rainfall (mm) Condition  UV Index
# 1              0.3     Rainy         7
# 3              0.4     Sunny        10
# 4              0.4     Foggy         6
# ...

# %%
#----------------------------------------------------------------------
